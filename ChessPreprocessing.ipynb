# %%
#The two lines below are colab specific. I will include the file

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7b33b72-1fb0-4606-b04c-436ebefc2d53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7b33b72-1fb0-4606-b04c-436ebefc2d53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
myfile = open("lichess_tournament_2022.12.03_EcJR7jAC_hourly-bullet.txt", "rt") # open lorem.txt for reading text
contents = myfile.read()         # read the entire file to string
myfile.close()                   # close the file
print(contents)                  # print string contents
# Out:
# [Event "Hourly Bullet Arena"]
# [Site "https://lichess.org/Xzyxqsun"]
# [Date "2022.12.03"]
# [White "MixedUp"]
# [Black "auditor2018"]
# [Result "0-1"]
# [UTCDate "2022.12.03"]
# [UTCTime "20:56:50"]
# [WhiteElo "2378"]
# [BlackElo "2389"]
# [WhiteRatingDiff "-5"]
# [BlackRatingDiff "+6"]
# [Variant "Standard"]
# [TimeControl "60+0"]
# [ECO "B06"]
# [Termination "Normal"]
#
# 1. e4 g6 2. d4 Bg7 3. Nc3 d6 4. Be2 Nc6 5. Be3 e5 6. dxe5 dxe5 7. Nf3 Bg4 8. h3 Bxf3 9. Bxf3 Nd4 10. Bg4 Nf6 11. O-O Nxg4 12. hxg4 c6 13. f3 h5 14. gxh5 Rxh5 15. Bf2 Qg5 16. Qc1 Nxf3# 0-1
#
#
# [Event "Hourly Bullet Arena"]
# [Site "https://lichess.org/ADxQCHKa"]
# [Date "2022.12.03"]
# [White "KungFuMantis"]
# [Black "AbbotHayes"]
# [Result "0-1"]
# [UTCDate "2022.12.03"]
# [UTCTime "20:56:31"]
# [WhiteElo "2008"]
# [BlackElo "2290"]
# [WhiteRatingDiff "-2"]
# [BlackRatingDiff "+2"]
# [Variant "Standard"]
# [TimeControl "60+0"]
# [ECO "C00"]
# [Termination "Normal"]
#
# ...

# %%
mylines = []                             # Declare an empty list named mylines.
with open ('lichess_tournament_2022.12.03_EcJR7jAC_hourly-bullet.txt', 'rt') as myfile: # Open lichess_pgn_(etc).txt for reading text data.
    for myline in myfile:                # For each line, stored as myline,
        mylines.append(myline)           # add its contents to mylines.
print(mylines)                           # Print the list.
# Out:
# ['[Event "Hourly Bullet Arena"]\n', '[Site "https://lichess.org/Xzyxqsun"]\n', '[Date "2022.12.03"]\n', '[White "MixedUp"]\n', '[Black "auditor2018"]\n', '[Result "0-1"]\n', '[UTCDate "2022.12.03"]\n', '[UTCTime "20:56:50"]\n', '[WhiteElo "2378"]\n', '[BlackElo "2389"]\n', '[WhiteRatingDiff "-5"]\n', '[BlackRatingDiff "+6"]\n', '[Variant "Standard"]\n', '[TimeControl "60+0"]\n', '[ECO "B06"]\n', '[Termination "Normal"]\n', '\n', '1. e4 g6 2. d4 Bg7 3. Nc3 d6 4. Be2 Nc6 5. Be3 e5 6. dxe5 dxe5 7. Nf3 Bg4 8. h3 Bxf3 9. Bxf3 Nd4 10. Bg4 Nf6 11. O-O Nxg4 12. hxg4 c6 13. f3 h5 14. gxh5 Rxh5 15. Bf2 Qg5 16. Qc1 Nxf3# 0-1\n', '\n', '\n', '[Event "Hourly Bullet Arena"]\n', '[Site "https://lichess.org/ADxQCHKa"]\n', '[Date "2022.12.03"]\n', '[White "KungFuMantis"]\n', '[Black "AbbotHayes"]\n', '[Result "0-1"]\n', '[UTCDate "2022.12.03"]\n', '[UTCTime "20:56:31"]\n', '[WhiteElo "2008"]\n', '[BlackElo "2290"]\n', '[WhiteRatingDiff "-2"]\n', '[BlackRatingDiff "+2"]\n', '[Variant "Standard"]\n', '
# ...

# %%
i = 1
#935 games played in total in this chess tournament
#When using full dataset instead of one game, will have to change 17*i
print(mylines[17*i])
# Out:
# 1. e4 g6 2. d4 Bg7 3. Nc3 d6 4. Be2 Nc6 5. Be3 e5 6. dxe5 dxe5 7. Nf3 Bg4 8. h3 Bxf3 9. Bxf3 Nd4 10. Bg4 Nf6 11. O-O Nxg4 12. hxg4 c6 13. f3 h5 14. gxh5 Rxh5 15. Bf2 Qg5 16. Qc1 Nxf3# 0-1

# %%
z = 1

#Place each pair of moves into tuples, such that: [(e4, g6), (d4, Bg7), etc.] While loop to do this for each match.
for x in mylines[17*i]:
